# %% [markdown]
# <a href="https://colab.research.google.com/github/aslbekrazzoqberdi/Colab_data/blob/main/5_Handle_Missing_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone 'https://github.com/codebasics/py.git'
! pip install geopandas
# Out:
# Cloning into 'py'...
# remote: Enumerating objects: 2910, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 2910 (delta 0), reused 3 (delta 0), pack-reused 2904
# Receiving objects: 100% (2910/2910), 196.66 MiB | 25.77 MiB/s, done.
# Resolving deltas: 100% (1121/1121), done.
# Updating files: 100% (1388/1388), done.
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/py/pandas/5_handling_missing_data_fillna_dropna_interpolate/weather_data.csv')
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
df.day[1]
# Out:
# '1/4/2017'

# %%
df.set_index('day', inplace=True)

# %%
df
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           NaN        9.0   Sunny
# 1/5/2017          28.0        NaN    Snow
# 1/6/2017           NaN        7.0     NaN
# 1/7/2017          32.0        NaN    Rain
# 1/8/2017           NaN        NaN   Sunny
# 1/9/2017           NaN        NaN     NaN
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
new_df = df.fillna(7)
new_df
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           7.0        9.0   Sunny
# 1/5/2017          28.0        7.0    Snow
# 1/6/2017           7.0        7.0       7
# 1/7/2017          32.0        7.0    Rain
# 1/8/2017           7.0        7.0   Sunny
# 1/9/2017           7.0        7.0       7
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
new_df2 = df.fillna({
    'temperature':0
})
new_df2
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           0.0        9.0   Sunny
# 1/5/2017          28.0        NaN    Snow
# 1/6/2017           0.0        7.0     NaN
# 1/7/2017          32.0        NaN    Rain
# 1/8/2017           0.0        NaN   Sunny
# 1/9/2017           0.0        NaN     NaN
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
new_df3 = df.fillna(method = 'ffill')
new_df3
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017          32.0        9.0   Sunny
# 1/5/2017          28.0        9.0    Snow
# 1/6/2017          28.0        7.0    Snow
# 1/7/2017          32.0        7.0    Rain
# 1/8/2017          32.0        7.0   Sunny
# 1/9/2017          32.0        7.0   Sunny
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
df
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           NaN        9.0   Sunny
# 1/5/2017          28.0        NaN    Snow
# 1/6/2017           NaN        7.0     NaN
# 1/7/2017          32.0        NaN    Rain
# 1/8/2017           NaN        NaN   Sunny
# 1/9/2017           NaN        NaN     NaN
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
new_df
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           7.0        9.0   Sunny
# 1/5/2017          28.0        7.0    Snow
# 1/6/2017           7.0        7.0       7
# 1/7/2017          32.0        7.0    Rain
# 1/8/2017           7.0        7.0   Sunny
# 1/9/2017           7.0        7.0       7
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
df
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           NaN        9.0   Sunny
# 1/5/2017          28.0        NaN    Snow
# 1/6/2017           NaN        7.0     NaN
# 1/7/2017          32.0        NaN    Rain
# 1/8/2017           NaN        NaN   Sunny
# 1/9/2017           NaN        NaN     NaN
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
new_df4 = df.fillna(method = 'bfill')
new_df4
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017          28.0        9.0   Sunny
# 1/5/2017          28.0        7.0    Snow
# 1/6/2017          32.0        7.0    Rain
# 1/7/2017          32.0        8.0    Rain
# 1/8/2017          34.0        8.0   Sunny
# 1/9/2017          34.0        8.0  Cloudy
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
df
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           NaN        9.0   Sunny
# 1/5/2017          28.0        NaN    Snow
# 1/6/2017           NaN        7.0     NaN
# 1/7/2017          32.0        NaN    Rain
# 1/8/2017           NaN        NaN   Sunny
# 1/9/2017           NaN        NaN     NaN
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
new_df5 = df.fillna(method = "ffill", limit=1)
new_df5
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017          32.0        9.0   Sunny
# 1/5/2017          28.0        9.0    Snow
# 1/6/2017          28.0        7.0    Snow
# 1/7/2017          32.0        7.0    Rain
# 1/8/2017          32.0        NaN   Sunny
# 1/9/2017           NaN        NaN   Sunny
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %% [markdown]
# ###  INTERPOLATE

# %%
df.interpolate()
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017     32.000000       6.00    Rain
# 1/4/2017     30.000000       9.00   Sunny
# 1/5/2017     28.000000       8.00    Snow
# 1/6/2017     30.000000       7.00     NaN
# 1/7/2017     32.000000       7.25    Rain
# 1/8/2017     32.666667       7.50   Sunny
# 1/9/2017     33.333333       7.75     NaN
# 1/10/2017    34.000000       8.00  Cloudy
# 1/11/2017    40.000000      12.00   Sunny

# %%
df
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           NaN        9.0   Sunny
# 1/5/2017          28.0        NaN    Snow
# 1/6/2017           NaN        7.0     NaN
# 1/7/2017          32.0        NaN    Rain
# 1/8/2017           NaN        NaN   Sunny
# 1/9/2017           NaN        NaN     NaN
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
df.dropna()
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
df
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           NaN        9.0   Sunny
# 1/5/2017          28.0        NaN    Snow
# 1/6/2017           NaN        7.0     NaN
# 1/7/2017          32.0        NaN    Rain
# 1/8/2017           NaN        NaN   Sunny
# 1/9/2017           NaN        NaN     NaN
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
df.fillna(25)
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017          25.0        9.0   Sunny
# 1/5/2017          28.0       25.0    Snow
# 1/6/2017          25.0        7.0      25
# 1/7/2017          32.0       25.0    Rain
# 1/8/2017          25.0       25.0   Sunny
# 1/9/2017          25.0       25.0      25
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
df9 = df['temperature'].mean()
df9
# Out:
# 33.2

# %%
df.fillna(df9)
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017          33.2        9.0   Sunny
# 1/5/2017          28.0       33.2    Snow
# 1/6/2017          33.2        7.0    33.2
# 1/7/2017          32.0       33.2    Rain
# 1/8/2017          33.2       33.2   Sunny
# 1/9/2017          33.2       33.2    33.2
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny
