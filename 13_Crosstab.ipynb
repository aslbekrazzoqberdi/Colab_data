# %% [markdown]
# <a href="https://colab.research.google.com/github/aslbekrazzoqberdi/Colab_data/blob/main/13_Crosstab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone 'https://github.com/codebasics/py.git'
! pip install geopandas
# Out:
# Cloning into 'py'...
# remote: Enumerating objects: 2910, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 2910 (delta 0), reused 2 (delta 0), pack-reused 2904
# Receiving objects: 100% (2910/2910), 196.66 MiB | 22.60 MiB/s, done.
# Resolving deltas: 100% (1121/1121), done.
# Updating files: 100% (1388/1388), done.
# ...

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/py/pandas/13_crosstab/survey.xls')
df
# Out:
#       Name Nationality     Sex  Age Handedness
# 0    Kathy         USA  Female   23      Right
# 1    Linda         USA  Female   18      Right
# 2    Peter         USA    Male   19      Right
# 3     John         USA    Male   22       Left
# 4   Fatima   Bangadesh  Female   31       Left
# 5    Kadir   Bangadesh    Male   25       Left
# 6   Dhaval       India    Male   35       Left
# 7   Sudhir       India    Male   31       Left
# 8   Parvir       India    Male   37      Right
# 9      Yan       China  Female   52      Right
# 10    Juan       China  Female   58       Left
# 11   Liang       China    Male   43       Left

# %%
pd.crosstab(df.Nationality, df.Handedness)
# Out:
# Handedness   Left  Right
# Nationality
# Bangadesh       2      0
# China           2      1
# India           2      1
# USA             1      3

# %%
pd.crosstab(df.Nationality, df.Sex)
# Out:
# Sex          Female  Male
# Nationality
# Bangadesh         1     1
# China             2     1
# India             0     3
# USA               2     2
